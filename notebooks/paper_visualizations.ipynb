# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

# %%
primary = pd.read_csv('../data/meta/meta_primary.tsv', sep='\t')
organoid = pd.read_csv('../data/meta/organoids_tsne.tsv', sep='\t')

# %%
primary
# Out:
#                               Cell              Area Individual  Age  \
# 0           AAACCTGAGCTGCCCA_50646             motor       GW14   14
# 1           AAACCTGAGCTTATCG_50647             motor       GW14   14
# 2           AAACCTGAGTATGACA_50652             motor       GW14   14
# 3           AAACCTGAGTCGCCGT_50654             motor       GW14   14
# 4           AAACCTGCACCAGCAC_50657             motor       GW14   14
# ...                            ...               ...        ...  ...
# 189404  CS22_CTTAACTCAGTAGAGC_6016  Occipital cortex       CS22   10
# 189405  CS22_GGATGTTTCGACCAGC_6380  Occipital cortex       CS22   10
# 189406  CS22_GCTGCTTAGCACCGTC_6308  Occipital cortex       CS22   10
# 189407  CS22_ATAGACCTCCTAGTGA_5271  Occipital cortex       CS22   10
# 189408  CS22_CCGGGATTCAAGATCC_5645  Occipital cortex       CS22   10
#
#                Class         State                Type             Subtype  \
# ...
